# %% [markdown]
# <a href="https://colab.research.google.com/github/sharminnipu/US_Accident_Data_Analysis/blob/main/us_accidents_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # US Accidents Exploratory Data Analysis(2016 - 2020)
#
# TODO - talk about EDA
#
# TODO - talk about the datatset(source,what it contains,how it will be usefull)
#    - Kaggle
#    - information about accidents
#    - can use useful to prevent accidents
#    - mention that this does not containt data about New York.

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/sobhanmoosavi/us-accidents'
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sharminnipu
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 117M/117M [00:01<00:00, 82.3MB/s]

# %%
data_filename='/content/us-accidents/US_Accidents_Dec20_updated.csv'

# %% [markdown]
# ## Data Preparations & Data Cleaning
# 1. Loading the file using Pandas
# 2. Look at some information about the data & columns
# 3. Fix any missing or incorrect values

# %%
import pandas as pd

# %%
df=pd.read_csv(data_filename)

# %%
df
# Out:
#                 ID  Severity  ... Nautical_Twilight Astronomical_Twilight
# 0        A-2716600         3  ...             Night                 Night
# 1        A-2716601         2  ...             Night                 Night
# 2        A-2716602         2  ...             Night                   Day
# 3        A-2716603         2  ...             Night                   Day
# 4        A-2716604         2  ...               Day                   Day
# ...            ...       ...  ...               ...                   ...
# 1516059  A-4239402         2  ...               Day                   Day
# 1516060  A-4239403         2  ...               Day                   Day
# 1516061  A-4239404         2  ...               Day                   Day
# 1516062  A-4239405         2  ...               Day                   Day
# 1516063  A-4239406         2  ...               Day                   Day
#
# [1516064 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516064 entries, 0 to 1516063
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   ID                     1516064 non-null  object
#  1   Severity               1516064 non-null  int64
#  2   Start_Time             1516064 non-null  object
#  3   End_Time               1516064 non-null  object
#  4   Start_Lat              1516064 non-null  float64
#  5   Start_Lng              1516064 non-null  float64
#  6   End_Lat                1516064 non-null  float64
#  7   End_Lng                1516064 non-null  float64
#  8   Distance(mi)           1516064 non-null  float64
#  9   Description            1516064 non-null  object
#  10  Number                 469969 non-null   float64
#  11  Street                 1516064 non-null  object
#  12  Side                   1516064 non-null  object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat  ...  Wind_Speed(mph)  Precipitation(in)
# count  1.516064e+06  1.516064e+06  ...     1.387202e+06       1.005515e+06
# mean   2.238630e+00  3.690056e+01  ...     7.630812e+00       8.477855e-03
# std    6.081481e-01  5.165653e+00  ...     5.637364e+00       1.293168e-01
# min    1.000000e+00  2.457022e+01  ...     0.000000e+00       0.000000e+00
# 25%    2.000000e+00  3.385422e+01  ...     4.600000e+00       0.000000e+00
# 50%    2.000000e+00  3.735113e+01  ...     7.000000e+00       0.000000e+00
# 75%    2.000000e+00  4.072593e+01  ...     1.040000e+01       0.000000e+00
# max    4.000000e+00  4.900058e+01  ...     9.840000e+02       2.400000e+01
#
# [8 rows x 14 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df=df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# Percentage of missing values per columns

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Number                   1046095
# Precipitation(in)         510549
# Wind_Chill(F)             449316
# Wind_Speed(mph)           128862
# Humidity(%)                45509
# Visibility(mi)             44211
# Weather_Condition          44007
# Temperature(F)             43033
# Wind_Direction             41858
# Pressure(in)               36274
# Weather_Timestamp          30264
# Airport_Code                4248
# Timezone                    2302
# Zipcode                      935
# Sunrise_Sunset                83
# Civil_Twilight                83
# Nautical_Twilight             83
# Astronomical_Twilight         83
# City                          83
# Country                        0
# Give_Way                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Turning_Loop                   0
# Traffic_Signal                 0
# Traffic_Calming                0
# Stop                           0
# ...

# %%
missing_percentages=df.isnull().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# Sunrise_Sunset           0.000055
# Civil_Twilight           0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# City                     0.000055
# Country                  0.000000
# Give_Way                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Turning_Loop             0.000000
# Traffic_Signal           0.000000
# Traffic_Calming          0.000000
# ...

# %%
#only missing values cloumn show me
missing_percentages[missing_percentages!=0]
# Out:
# Number                   0.690007
# Precipitation(in)        0.336760
# Wind_Chill(F)            0.296370
# Wind_Speed(mph)          0.084998
# Humidity(%)              0.030018
# Visibility(mi)           0.029162
# Weather_Condition        0.029027
# Temperature(F)           0.028385
# Wind_Direction           0.027610
# Pressure(in)             0.023926
# Weather_Timestamp        0.019962
# Airport_Code             0.002802
# Timezone                 0.001518
# Zipcode                  0.000617
# Sunrise_Sunset           0.000055
# Civil_Twilight           0.000055
# Nautical_Twilight        0.000055
# Astronomical_Twilight    0.000055
# City                     0.000055
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages[missing_percentages!=0].plot(kind='barh')

# %% [markdown]
# From the graph we can understand that there is most missing values columns in number which is 70% and lowest missing values columns in city,Astronomical twilight,Nautical twilight,civil twilight, sunrise sunset,zipcode timezone,and airport code which is 0% percentages.

# %% [markdown]
# ## Remove columns that we don't want to use.

# %% [markdown]
# ## Exploratory Analysis and Visulization
#  Coulmns we'll analyze:
#  1. City
#  2. State
#  3. Start_Time
#  4. Start_Lat,Start_Lng

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ### Analysis City

# %%
df.City
# Out:
# 0               Dublin
# 1               Dayton
# 2           Cincinnati
# 3           Cincinnati
# 4                Akron
#               ...
# 1516059      Riverside
# 1516060      San Diego
# 1516061         Orange
# 1516062    Culver City
# 1516063       Highland
# Name: City, Length: 1516064, dtype: object

# %%
cities=df.City.unique()
len(cities)
# Out:
# 10658

# %%
cities_by_accidents=df.City.value_counts()
cities_by_accidents
# Out:
# Los Angeles                     39984
# Miami                           36233
# Charlotte                       22203
# Houston                         20843
# Dallas                          19497
#                                 ...
# Manzanita                           1
# West Brooklyn                       1
# Garfield Heights                    1
# Belding                             1
# American Fork-Pleasant Grove        1
# Name: City, Length: 10657, dtype: int64

# %%
cities_by_accidents[:20]
# Out:
# Los Angeles     39984
# Miami           36233
# Charlotte       22203
# Houston         20843
# Dallas          19497
# Sacramento      18431
# Orlando         16169
# Portland        14805
# San Diego       14090
# Minneapolis     12653
# Atlanta         11854
# Chicago         11507
# Saint Paul      10084
# Phoenix          9934
# Raleigh          9516
# San Jose         9362
# Richmond         8472
# Nashville        8381
# Riverside        8201
# Jacksonville     7815
# Name: City, dtype: int64

# %%
cities_by_accidents[:20].plot(kind='barh')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.histplot(cities_by_accidents,log_scale=True)

# %%
cities_by_accidents[cities_by_accidents==1]
# Out:
# South Paris                     1
# Aberdeen Proving Ground         1
# Rebecca                         1
# Hiltons                         1
# Jeanerette                      1
#                                ..
# Manzanita                       1
# West Brooklyn                   1
# Garfield Heights                1
# Belding                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1167, dtype: int64

# %%
high_accident_cities=cities_by_accidents[cities_by_accidents>=1000]
low_accident_cities=cities_by_accidents[cities_by_accidents<1000]

# %%
len(high_accident_cities)/len(cities)
# Out:
# 0.023550384687558643

# %%
sns.distplot(high_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(low_accident_cities)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#check value have in column of state
'NY' in df.State
# Out:
# False

# %% [markdown]
# ## Analysis State

# %%
df.State
# Out:
# 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 1516059    CA
# 1516060    CA
# 1516061    CA
# 1516062    CA
# 1516063    CA
# Name: State, Length: 1516064, dtype: object

# %%
states_by_accidents=df.State.value_counts()
states_by_accidents
# Out:
# CA    448833
# FL    153007
# OR     87484
# TX     75142
# NY     60974
# MN     52345
# VA     51198
# NC     50159
# PA     42844
# IL     41709
# MD     35320
# UT     33218
# GA     31111
# AZ     30185
# NJ     29850
# SC     28090
# MI     27775
# WA     22999
# OH     22044
# TN     21874
# CO     19809
# LA     19250
# MO     16949
# CT     15194
# IN     11736
# AL      9375
# WI      7919
# MA      6121
# KY      5671
# OK      5592
# KS      5146
# IA      4780
# AR      4373
# ID      4061
# NH      3826
# DC      3788
# RI      3766
# NV      3681
# MT      3306
# WV      3242
# MS      2790
# DE      2331
# ME      2202
# NE      2178
# NM      1467
# ND       455
# VT       352
# WY       330
# SD       213
# Name: State, dtype: int64

# %%
states_by_accidents[:5]
# Out:
# CA    448833
# FL    153007
# OR     87484
# TX     75142
# NY     60974
# Name: State, dtype: int64

# %%
states_by_accidents[:20].plot(kind='barh')

# %%
high_accident_state=states_by_accidents[states_by_accidents>=100000]
low_accident_state=states_by_accidents[states_by_accidents<100000]

# %%
high_accident_state
# Out:
# CA    448833
# FL    153007
# Name: State, dtype: int64

# %%
low_accident_state
# Out:
# OR    87484
# TX    75142
# NY    60974
# MN    52345
# VA    51198
# NC    50159
# PA    42844
# IL    41709
# MD    35320
# UT    33218
# GA    31111
# AZ    30185
# NJ    29850
# SC    28090
# MI    27775
# WA    22999
# OH    22044
# TN    21874
# CO    19809
# LA    19250
# MO    16949
# CT    15194
# IN    11736
# AL     9375
# WI     7919
# MA     6121
# KY     5671
# OK     5592
# KS     5146
# IA     4780
# AR     4373
# ID     4061
# NH     3826
# DC     3788
# RI     3766
# NV     3681
# MT     3306
# WV     3242
# MS     2790
# DE     2331
# ME     2202
# NE     2178
# NM     1467
# ND      455
# VT      352
# WY      330
# SD      213
# Name: State, dtype: int64

# %% [markdown]
# ### Analysis Start Time

# %%
df.Start_Time
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:15:39
# 4         2016-02-08 06:51:45
#                   ...
# 1516059   2019-08-23 18:03:25
# 1516060   2019-08-23 19:11:30
# 1516061   2019-08-23 19:00:21
# 1516062   2019-08-23 19:00:21
# 1516063   2019-08-23 18:52:06
# Name: Start_Time, Length: 1516064, dtype: datetime64[ns]

# %%
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %%
df.Start_Time=pd.to_datetime(df.Start_Time)
df.Start_Time[0]
# Out:
# Timestamp('2016-02-08 00:37:08')

# %% [markdown]
# - Figure out how to show percentages

# %%
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - A high percentage of accidents occur between 12pm to 7pm(probaply people in a hurry to get to back home or reach to working place).
# - Next highest percentage of accident is 6am to 10 am.

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Is the distribution of accidents by hour the same on weekends as an weekdays.

# %%
sunday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sunday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
monday_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# On sunday,the peak occurs between 12am and 6pm,unlike weekdays.

# %%
sns.distplot(df.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Graph says that On December month accident occurred mostly which is winter season.

# %%
df_2019=df[df.Start_Time.dt.year==2016]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Can we explain the month wise trends of accidents?
# - Much data is missing in 2016 and 2020.

# %% [markdown]
# ### Analysis Start_Latitude & Longitude

# %%
df.Start_Lat
# Out:
# 0          40.10891
# 1          39.86542
# 2          39.10266
# 3          39.10148
# 4          41.06213
#              ...
# 1516059    34.00248
# 1516060    32.76696
# 1516061    33.77545
# 1516062    33.99246
# 1516063    34.13393
# Name: Start_Lat, Length: 1516064, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.09286
# 1          -84.06280
# 2          -84.52468
# 3          -84.52341
# 4          -81.53784
#              ...
# 1516059   -117.37936
# 1516060   -117.14806
# 1516061   -117.84779
# 1516062   -118.40302
# 1516063   -117.23092
# Name: Start_Lng, Length: 1516064, dtype: float64

# %%
sample_df = df.sample(int(0.1 *len(df)))

# %%
sns.scatterplot(x=sample_df.Start_Lng,y=sample_df.Start_Lat,size=0.001)

# %%
import folium

# %%
lat,lng=df.Start_Lat[0],df.Start_Lng[0]
lat,lng
# Out:
# (40.10891, -83.09286)

# %%
from folium.plugins import HeatMap

# %%
sample_df=df.sample(int(0.01 *len(df)))
lat_lng_pair=list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
map=folium.Map()
HeatMap(lat_lng_pair).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# ## Ask &  answer Questions
# 1. Are there more accidents in warmer or colder areas?
# 2. Which 5 states have the highest number of accidents?How about per capita?
# 3. Does New York show up in thr data?If yes,is the count lower if this most populated city.
# 4. Among the top 100 cities in number of accidents,which states do they belong to most frequently.
# 5. What time of the day are accidents most frequent in? **ANSWER**
# 6. Which days of the week have the most accidents?
# 7. Which months have the most accidents?
# 8. What is the trend of accidents year over year(decreasing/increasing?)

# %% [markdown]
# ## Summary and Conclusion
#
#
# Insights:
# - No data for New York
# - California and Florida are highest accidents occurred in state
# - The number of accidents per city descreases exponentially.
# - Less than 2% of cities have more than 1000 yearly accidents.
# - Over 1100 cities have repoted just one accident(need to investingate)
